# %%
# question 1

# %%
# gpt-3.5-turbo

import openai 
import os
from getpass import getpass

# get api key
os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ')
openai.api_key = os.environ['OPENAI_API_KEY'] 

# ask question function (gpt only)
def ask_math_question(question, model="gpt-3.5-turbo"):
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": question}],
        temperature=0.2
    )
    # Extract response text
    return response.choices[0].message.content.strip() 

# ask question
question = r"""
integral from 1 to 2 of (x+x^2)/x^4
"""

# get answer
answer = ask_math_question(question)

# print answer
print(answer)
# Out:
# Enter your OpenAI API key:  ········
# To find the integral of (x + x^2)/x^4 from 1 to 2, we first need to simplify the expression:
#
# (x + x^2)/x^4 = x/x^4 + x^2/x^4
# = 1/x^3 + 1/x^2
#
# Now we can integrate term by term:
#
# ∫(1/x^3) dx + ∫(1/x^2) dx
# = -1/(2x^2) - 1/x + C
#
# Now we can evaluate the integral from 1 to 2:
#
# [-1/(2(2)^2) - 1/2] - [-1/(2(1)^2) - 1/1]
# = [-1/8 - 1/2] - [-1/2 - 1]
# = [-9/8] - [-3/2]
# = -9/8 + 3/2
# = -9/8 + 12/8
# = 3/8
#
# Therefore, the integral of (x + x^2)/x^4 from 1 to 2 is 3/8.

# %%
# gpt-4.1-2025-04-14

import openai 
import os
from getpass import getpass

# get api key
os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ')
openai.api_key = os.environ['OPENAI_API_KEY'] 

# ask question function (gpt only)
def ask_math_question(question, model="gpt-4.1-2025-04-14"):
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": question}],
        temperature=0.2
    )
    # Extract response text
    return response.choices[0].message.content.strip() 

# ask question
question = r"""
integral from 1 to 2 of (x+x^2)/x^4
"""

# get answer
answer = ask_math_question(question)

# print answer
print(answer)
# Out:
# Enter your OpenAI API key:  ········
# Let's compute the integral:
#
# \[
# \int_{1}^{2} \frac{x + x^2}{x^4} \, dx
# \]
#
# First, **simplify the integrand**:
#
# \[
# \frac{x + x^2}{x^4} = \frac{x}{x^4} + \frac{x^2}{x^4} = x^{-3} + x^{-2}
# \]
#
# So the integral becomes:
#
# \[
# \int_{1}^{2} (x^{-3} + x^{-2}) \, dx
# \]
#
# Now, **integrate term by term**:
#
# 1. \(\int x^{-3} dx = \frac{x^{-2}}{-2} = -\frac{1}{2} x^{-2}\)
# 2. \(\int x^{-2} dx = \frac{x^{-1}}{-1} = -x^{-1}\)
#
# So the **antiderivative** is:
#
# \[
# -\frac{1}{2} x^{-2} - x^{-1}
# \]
#
# Now, **evaluate from 1 to 2**:
#
# \[
# \left[ -\frac{1}{2} x^{-2} - x^{-1} \right]_{1}^{2}
# \]
#
# Plug in the limits:
#
# At \(x=2\):
#
# \[
# -\frac{1}{2} (2^{-2}) - (2^{-1}) = -\frac{1}{2} \cdot \frac{1}{4} - \frac{1}{2} = -\frac{1}{8} - \frac{1}{2}
# \]
#
# At \(x=1\):
#
# \[
# -\frac{1}{2} (1^{-2}) - (1^{-1}) = -\frac{1}{2} \cdot 1 - 1 = -\frac{1}{2} - 1 = -\frac{3}{2}
# \]
#
# Subtract:
#
# \[
# ...

# %%
# cmbagent

import copy
import cmbagent

import openai 
import os
from getpass import getpass

# get api key
os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ')
openai.api_key = os.environ['OPENAI_API_KEY'] 

task = r"""
integral from 1 to 2 of (x+x^2)/x^4
"""

results = cmbagent.one_shot(task,
                   max_rounds=10,
                   agent='engineer',
                   engineer_model='gpt-4.1-2025-04-14',
                   # work_dir="/mnt/d/GitHub/math_llm_benchmark",
                  )
# Out:
# Enter your OpenAI API key:  ········
# integral from 1 to 2 of (x+x^2)/x^4
#
#
# --------------------------------------------------------------------------------
#
# Calling engineer...
#
#              Model    agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 engineer 0.00663           1593                431          2024
# **Code Explanation:**
#
# This code computes the definite integral of the function (x + x^2) / x^4 from x = 1 to x = 2. The function is first simplified to (1 + x) / x^3. The code uses the `sympy` library for symbolic integration to obtain the exact value, and also evaluates the result numerically. The result is printed with high precision. The result is also saved to a text file in the `data/` directory.
#
# **Python Code:**
#
# ```python
# import sympy as sp
# import os
#
# def main():
#     """
#     Computes the definite integral of (x + x^2) / x^4 from x = 1 to x = 2,
# ...

# %%
# gpt-3.5-turbo FAILS
# gpt-4.1-2025-04-14 AND cmbagent (model gpt-4.1-2025-04-14) SUCCEED

# %%
# question 2

# %%
# gpt-4.1-2025-04-14

import openai 
import os
from getpass import getpass

# get api key
os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ')
openai.api_key = os.environ['OPENAI_API_KEY'] 

# ask question function (gpt only)
def ask_math_question(question, model="gpt-4.1-2025-04-14"):
    response = openai.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": question}],
        temperature=0.2
    )
    # Extract response text
    return response.choices[0].message.content.strip() 

# ask question
question = r"""
1st order taylor series expansion in x=3 of sqrt(1+x)*(x/cos(x))
"""

# get answer
answer = ask_math_question(question)

# print answer
print(answer)
# Out:
# Enter your OpenAI API key:  ········
# Let's compute the **1st order Taylor series expansion** of the function
# \[ f(x) = \sqrt{1+x} \cdot \frac{x}{\cos(x)} \]
# about \( x = 3 \).
#
# ### **Step 1: Compute \( f(3) \)**
# \[
# f(3) = \sqrt{1+3} \cdot \frac{3}{\cos(3)} = \sqrt{4} \cdot \frac{3}{\cos(3)} = 2 \cdot \frac{3}{\cos(3)} = \frac{6}{\cos(3)}
# \]
#
# ---
#
# ### **Step 2: Compute \( f'(x) \)**
#
# Let’s use the product and quotient rules:
#
# Let \( u(x) = \sqrt{1+x} \), \( v(x) = \frac{x}{\cos(x)} \).
#
# - \( u'(x) = \frac{1}{2}(1+x)^{-1/2} \)
# - \( v(x) = \frac{x}{\cos(x)} \)
# - \( v'(x) = \frac{\cos(x) \cdot 1 - x \cdot (-\sin(x))}{\cos^2(x)} = \frac{\cos(x) + x\sin(x)}{\cos^2(x)} \)
#
# So,
# \[
# f'(x) = u'(x) v(x) + u(x) v'(x)
# \]
# \[
# = \frac{1}{2}(1+x)^{-1/2} \cdot \frac{x}{\cos(x)} + \sqrt{1+x} \cdot \frac{\cos(x) + x\sin(x)}{\cos^2(x)}
# \]
#
# ---
#
# ### **Step 3: Evaluate \( f'(3) \)**
#
# - \( (1+3)^{-1/2} = 4^{-1/2} = \frac{1}{2} \)
# ...

# %%
# cmbagent

import copy
import cmbagent

import openai 
import os
from getpass import getpass

# get api key
os.environ['OPENAI_API_KEY'] = getpass('Enter your OpenAI API key: ')
openai.api_key = os.environ['OPENAI_API_KEY'] 

task = r"""
1st order taylor series expansion in x=3 of sqrt(1+x)*(x/cos(x))
"""

results = cmbagent.one_shot(task,
                   max_rounds=10,
                   agent='engineer',
                   engineer_model='gpt-4.1-2025-04-14',
                   # work_dir="/mnt/d/GitHub/math_llm_benchmark",
                  )
# Out:
# Enter your OpenAI API key:  ········
# 1st order taylor series expansion in x=3 of sqrt(1+x)*(x/cos(x))
#
#
# --------------------------------------------------------------------------------
#
# Calling engineer...
#
#              Model    agent    Cost  Prompt Tokens  Completion Tokens  Total Tokens
# gpt-4.1-2025-04-14 engineer 0.00917           1599                747          2346
# **Code Explanation:**
#
# This code computes the first-order Taylor series expansion of the function f(x) = sqrt(1 + x) * (x / cos(x)) around x = 3. It uses SymPy for symbolic differentiation and evaluation. The result is printed in both symbolic and numerical forms, and the Taylor polynomial is saved to a text file in the 'data/' directory.
#
# **Python Code:**
#
# ```python
# import sympy as sp
# import os
# import time
#
# def taylor_series_first_order(func, var, a):
#     """
#     Compute the first-order Taylor series expansion of a function at a point.
#
#     Parameters
#     ----------
# ...

# %%
"""
Taylor polynomial saved to file: data/taylor_first_order_sqrt1px_x_over_cosx_at3_1748335695.txt

Here is the answer, pasted from the file:

First-order Taylor expansion of sqrt(1+x)*(x/cos(x)) at x=3:
Symbolic form:
(x - 3)*(11/(4*cos(3)) + 6*sin(3)/cos(3)**2) + 6/cos(3)

Numerical evaluation at x=3: -6.060651995447963
Numerical evaluation at x=3.1: -6.252039379499928
"""

# gpt-4.1-2025-04-14 WRONG
# cmbagent (gpt-4.1-2025-04-14) RIGHT
